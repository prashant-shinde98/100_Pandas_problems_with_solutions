# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series

# %%
# Create Series
a = [1,2,3,4,5]
a = pd.Series(a)
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# 2 using dict
x = {'a':1, 'b':2, 'c':3}
x = pd.Series(x)
x
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# Series Attributes

# %%
# 3 size
a.size
# Out:
# 5

# %%
# 4 dtype
a.dtype
# Out:
# dtype('int64')

# %%
# 5 name
x.name

# %%
# 6
x.is_unique
# Out:
# True

# %%
# 7 index
x.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
# 8 values
x.values
# Out:
# array([1, 2, 3], dtype=int64)

# %%
# 9 memory usage
x.memory_usage
# Out:
# <bound method Series.memory_usage of a    1
# b    2
# c    3
# dtype: int64>

# %% [markdown]
# reading file

# %%
# 10 using read_csv         -> csv convert to df by default
# single column             -> squeeze = True to make it series
pd.read_csv('file_name', squeeze= True)

# %%
# 11 for multiple column
pd.read_csv('file_name', index_col='col_name', squeeze= True)

# %% [markdown]
# Series Methods

# %%
# 12 head
x.head()
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# 13 tail
a.tail()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# 14 sample
x.sample(1)
# Out:
# b    2
# dtype: int64

# %%
# 15 value count
a.value_counts()
# Out:
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64

# %%
# 16 sorting
x.sort_values()
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# 17 permanant
x.sort_values(inplace= True)

# %%
# 18 ascending reverse
x.sort_values(ascending= False)
# Out:
# c    3
# b    2
# a    1
# dtype: int64

# %%
# 19 sort index
x.sort_index()
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# 20 to_numpy
x.to_numpy()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
# 21  size
a.__sizeof__()
# Out:
# 172

# %% [markdown]
# Maths Methods

# %%
a = np.arange(1,100)
a = pd.Series(a)
a
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 94    95
# 95    96
# 96    97
# 97    98
# 98    99
# Length: 99, dtype: int32

# %%
# 22 count  -> count does not count missing values. whereas size measures them also
a.count()
# Out:
# 99

# %%
# 23 sum
a.sum()
# Out:
# 4950

# %%
# product
a.prod()
# Out:
# 0

# %%
# 25 mean
a.mean()
# Out:
# 50.0

# %%
# 26 mode
a.mode()
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 94    95
# 95    96
# 96    97
# 97    98
# 98    99
# Length: 99, dtype: int32

# %%
# 27 min
a.min()
# Out:
# 1

# %%
# 29 max
a.max()
# Out:
# 99

# %%
# 30 std
a.std()
# Out:
# 28.722813232690143

# %%
# 31 varience
a.var()
# Out:
# 825.0

# %%
#32 describe
a.describe()
# Out:
# count    99.000000
# mean     50.000000
# std      28.722813
# min       1.000000
# 25%      25.500000
# 50%      50.000000
# 75%      74.500000
# max      99.000000
# dtype: float64

# %%
#33 rank
a.rank()
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
#       ...
# 94    95.0
# 95    96.0
# 96    97.0
# 97    98.0
# 98    99.0
# Length: 99, dtype: float64

# %% [markdown]
# ## DataFrame

# %%
# 34 create df
# using list
student = [[100,80,10], [90,70,7], [120,100,14]]
pd.DataFrame(student, columns=['iq', 'marks', 'package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14

# %%
# 35 using dict
student = {'iq': [100,80,10],
           'marks': [90,70,7],
           'package': [120,100,14]}
pd.DataFrame(student)
# Out:
#     iq  marks  package
# 0  100     90      120
# 1   80     70      100
# 2   10      7       14

# %%
# 36 using read csv
df = pd.read_csv('datasets/items.csv')
df
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# Atributes and Methods

# %%
# 37 shape
df.shape
# Out:
# (4622, 2)

# %%
# 38 dtypes
df.dtypes
# Out:
# item_name     object
# item_price    object
# dtype: object

# %%
# 39 index
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# 40 columns
df.columns
# Out:
# Index(['item_name', 'item_price'], dtype='object')

# %%
# 41 values
df.values
# Out:
# array([['Chips and Fresh Tomato Salsa', '$2.39 '],
#        ['Izze', '$3.39 '],
#        ['Nantucket Nectar', '$3.39 '],
#        ...,
#        ['Chicken Salad Bowl', '$11.25 '],
#        ['Chicken Salad Bowl', '$8.75 '],
#        ['Chicken Salad Bowl', '$8.75 ']], dtype=object)

# %%
# 42 head
df.head(2)
# Out:
#                       item_name item_price
# 0  Chips and Fresh Tomato Salsa     $2.39
# 1                          Izze     $3.39

# %%
# 43 tail
df.tail(2)
# Out:
#                item_name item_price
# 4620  Chicken Salad Bowl     $8.75
# 4621  Chicken Salad Bowl     $8.75

# %%
#44 sample
df.sample(2)
# Out:
#             item_name item_price
# 2997    Steak Burrito     $8.99
# 4125  Chicken Burrito     $8.75

# %%
# 45 describe
df.describe()
# Out:
#            item_name item_price
# count           4622       4572
# unique            50         78
# top     Chicken Bowl     $8.75
# freq             726        724

# %%
# 46 info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_name   4622 non-null   object
#  1   item_price  4572 non-null   object
# dtypes: object(2)
# memory usage: 72.3+ KB

# %%
# 47 null values
df.isnull().sum()
# Out:
# item_name      0
# item_price    50
# dtype: int64

# %%
# 48 duplicated
df.duplicated().sum()
# Out:
# 4393

# %%
# 49 rename
df.rename(columns={'item_name':'items_name'})
# Out:
#                                  items_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# 50 series to df
y = x.to_frame()

# %%
#51 query
y.query('a== 1')

# %% [markdown]
# Maths Methods

# %%
# 52 sum
df.sum()

# %%
# 53 sum row wise
df.sum(axis=1)

# %%
# 54 min/max/mode/mediun/std/var/mean  -> same as series

# %% [markdown]
# Selecting columns

# %%
# 55 
df['item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
# 56  -> 2D
df[['name']]

# %% [markdown]
# Selecting Rows

# %%
# 57 iloc -> position wise
#    loc -> label wise
df.iloc[0]
# Out:
# item_name     Chips and Fresh Tomato Salsa
# item_price                          $2.39
# Name: 0, dtype: object

# %%
# 58 multiple rows
df.iloc[0:5]
# Out:
#                                item_name item_price
# 0           Chips and Fresh Tomato Salsa     $2.39
# 1                                   Izze     $3.39
# 2                       Nantucket Nectar     $3.39
# 3  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                           Chicken Bowl    $16.98

# %%
# 59 fancy index
df.iloc[[1,3,6]]
# Out:
#                                item_name item_price
# 1                                   Izze     $3.39
# 3  Chips and Tomatillo-Green Chili Salsa     $2.39
# 6                          Side of Chips        NaN

# %%
# 60 using label
df.loc[3]
# Out:
# item_name     Chips and Tomatillo-Green Chili Salsa
# item_price                                   $2.39
# Name: 3, dtype: object

# %% [markdown]
# Selecting both row and cols

# %%
# 61 
df.iloc[0:3,0:]
# Out:
#                       item_name item_price
# 0  Chips and Fresh Tomato Salsa     $2.39
# 1                          Izze     $3.39
# 2              Nantucket Nectar     $3.39

# %%
# 62 boolean indexing
df[df.place.apply(len) >= 6]

# %%
ipl = pd.read_csv('datasets\IPL_Matches_2008_2022.csv')
ipl.head(2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\Prashant\AppData\Local\Temp\ipykernel_2724\1982619852.py:1: SyntaxWarning: invalid escape sequence '\I'
#   ipl = pd.read_csv('datasets\IPL_Matches_2008_2022.csv')
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney  Nitin Menon

# %% [markdown]
# Filtering DF

# %%
# 63 find all final winners
mask = ipl['MatchNumber'] == 'Final'
new_df = ipl[mask]
new_df[['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# 64 
ipl[ipl['MatchNumber'] == 'Final'][['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# 65how many super over occured
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# 66 how many match csk won in kolkatta
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# 67 toss winner is match winner in %%!
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ ipl.shape[0])*100
# Out:
# 51.473684210526315

# %% [markdown]
# Add new column

# %%
# 68 new one
ipl['country'] = 'india'
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#         WinningTeam    WonBy Margin  method Player_of_Match  \
# 0    Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1  Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney
#
#        Umpire2 country
# 0  Nitin Menon   india
# 1  Nitin Menon   india
#
# [2 rows x 21 columns]

# %%
# 69 from existing one
ipl['code'] = (ipl['Team1'].apply(lambda string: ''.join(word[0].upper() for word in string.split()))) +'v'+ (ipl['Team2'].apply(lambda string: ''.join(word[0].upper() for word in string.split())))
ipl.sample(1)
# Out:
#          ID     City        Date Season MatchNumber                  Team1  \
# 657  548353  Kolkata  2012-05-05   2012          47  Kolkata Knight Riders
#
#              Team2         Venue             TossWinner TossDecision  ...  \
# 657  Pune Warriors  Eden Gardens  Kolkata Knight Riders          bat  ...
#
#     WonBy Margin method  Player_of_Match  \
# 657  Runs    7.0    NaN        SP Narine
#
#                                           Team1Players  \
# 657  ['G Gambhir', 'BB McCullum', 'YK Pathan', 'JH ...
#
#                                           Team2Players    Umpire1  \
# 657  ['RV Uthappa', 'MJ Clarke', 'MK Pandey', 'SPD ...  BF Bowden
#
#          Umpire2 country    code
# 657  SK Tarapore   india  KKRvPW
#
# [1 rows x 22 columns]

# %% [markdown]
# Imp DF functions

# %%
# 70 astype  -> change dtype
ipl['MatchNumber'].astype('string')
# Out:
# 0            Final
# 1      Qualifier 2
# 2       Eliminator
# 3      Qualifier 1
# 4               70
#           ...
# 945              4
# 946              5
# 947              3
# 948              2
# 949              1
# Name: MatchNumber, Length: 950, dtype: string

# %%
# 71 freq of values
ipl['City'].value_counts()
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Dharamsala          9
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
# 72 sort values
ipl['Season'].sort_values()
# Out:
# 949    2007/08
# 917    2007/08
# 916    2007/08
# 915    2007/08
# 914    2007/08
#         ...
# 52        2022
# 53        2022
# 54        2022
# 56        2022
# 0         2022
# Name: Season, Length: 950, dtype: object

# %%
# 73 sort index
ipl['ID'].sort_index()
# Out:
# 0      1312200
# 1      1312199
# 2      1312198
# 3      1312197
# 4      1304116
#         ...
# 945     335986
# 946     335985
# 947     335984
# 948     335983
# 949     335982
# Name: ID, Length: 950, dtype: int64

# %%
# 74 set index
ipl.set_index('City')
# Out:
#                  ID        Date   Season  MatchNumber  \
# City
# Ahmedabad   1312200  2022-05-29     2022        Final
# Ahmedabad   1312199  2022-05-27     2022  Qualifier 2
# Kolkata     1312198  2022-05-25     2022   Eliminator
# Kolkata     1312197  2022-05-24     2022  Qualifier 1
# Mumbai      1304116  2022-05-22     2022           70
# ...             ...         ...      ...          ...
# Kolkata      335986  2008-04-20  2007/08            4
# Mumbai       335985  2008-04-20  2007/08            5
# Delhi        335984  2008-04-19  2007/08            3
# Chandigarh   335983  2008-04-19  2007/08            2
# Bangalore    335982  2008-04-18  2007/08            1
#
#                                   Team1                        Team2  \
# City
# Ahmedabad              Rajasthan Royals               Gujarat Titans
# Ahmedabad   Royal Challengers Bangalore             Rajasthan Royals
# Kolkata     Royal Challengers Bangalore         Lucknow Super Giants
# Kolkata                Rajasthan Royals               Gujarat Titans
# Mumbai              Sunrisers Hyderabad                 Punjab Kings
# ...                                 ...                          ...
# Kolkata           Kolkata Knight Riders              Deccan Chargers
# Mumbai                   Mumbai Indians  Royal Challengers Bangalore
# Delhi                  Delhi Daredevils             Rajasthan Royals
# Chandigarh              Kings XI Punjab          Chennai Super Kings
# Bangalore   Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                                  Venue  \
# City
# Ahmedabad             Narendra Modi Stadium, Ahmedabad
# Ahmedabad             Narendra Modi Stadium, Ahmedabad
# Kolkata                          Eden Gardens, Kolkata
# Kolkata                          Eden Gardens, Kolkata
# Mumbai                        Wankhede Stadium, Mumbai
# ...                                                ...
# Kolkata                                   Eden Gardens
# Mumbai                                Wankhede Stadium
# Delhi                                 Feroz Shah Kotla
# Chandigarh  Punjab Cricket Association Stadium, Mohali
# Bangalore                        M Chinnaswamy Stadium
#
#                              TossWinner TossDecision SuperOver  ...    WonBy  \
# City                                                            ...
# Ahmedabad              Rajasthan Royals          bat         N  ...  Wickets
# Ahmedabad              Rajasthan Royals        field         N  ...  Wickets
# Kolkata            Lucknow Super Giants        field         N  ...     Runs
# Kolkata                  Gujarat Titans        field         N  ...  Wickets
# Mumbai              Sunrisers Hyderabad          bat         N  ...  Wickets
# ...                                 ...          ...       ...  ...      ...
# Kolkata                 Deccan Chargers          bat         N  ...  Wickets
# Mumbai                   Mumbai Indians          bat         N  ...  Wickets
# Delhi                  Rajasthan Royals          bat         N  ...  Wickets
# Chandigarh          Chennai Super Kings          bat         N  ...     Runs
# Bangalore   Royal Challengers Bangalore        field         N  ...     Runs
#
#            Margin  method Player_of_Match  \
# City
# Ahmedabad     7.0     NaN       HH Pandya
# Ahmedabad     7.0     NaN      JC Buttler
# Kolkata      14.0     NaN      RM Patidar
# Kolkata       7.0     NaN       DA Miller
# Mumbai        5.0     NaN   Harpreet Brar
# ...           ...     ...             ...
# Kolkata       5.0     NaN       DJ Hussey
# Mumbai        5.0     NaN      MV Boucher
# Delhi         9.0     NaN     MF Maharoof
# Chandigarh   33.0     NaN      MEK Hussey
# Bangalore   140.0     NaN     BB McCullum
#
#                                                  Team1Players  \
# City
# Ahmedabad   ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# Ahmedabad   ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# Kolkata     ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# Kolkata     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# Mumbai      ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ...                                                       ...
# Kolkata     ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# Mumbai      ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# Delhi       ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# Chandigarh  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# Bangalore   ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                                  Team2Players        Umpire1  \
# City
# Ahmedabad   ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# Ahmedabad   ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# Kolkata     ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# Kolkata     ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# Mumbai      ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ...                                                       ...            ...
# Kolkata     ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# Mumbai      ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# Delhi       ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# Chandigarh  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# Bangalore   ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#                    Umpire2 country     code
# City
# Ahmedabad      Nitin Menon   india    RRvGT
# Ahmedabad      Nitin Menon   india   RCBvRR
# Kolkata           MA Gough   india  RCBvLSG
# Kolkata          VK Sharma   india    RRvGT
# Mumbai       NA Patwardhan   india    SHvPK
# ...                    ...     ...      ...
# Kolkata        K Hariharan   india   KKRvDC
# Mumbai           DJ Harper   india   MIvRCB
# Delhi       GA Pratapkumar   india    DDvRR
# Chandigarh      SL Shastri   india  KXPvCSK
# Bangalore      RE Koertzen   india  RCBvKKR
#
# [950 rows x 21 columns]

# %%
# 75 reset index
ipl.reset_index()
# Out:
#      index       ID        City        Date   Season  MatchNumber  \
# 0        0  1312200   Ahmedabad  2022-05-29     2022        Final
# 1        1  1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2        2  1312198     Kolkata  2022-05-25     2022   Eliminator
# 3        3  1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4        4  1304116      Mumbai  2022-05-22     2022           70
# ..     ...      ...         ...         ...      ...          ...
# 945    945   335986     Kolkata  2008-04-20  2007/08            4
# 946    946   335985      Mumbai  2008-04-20  2007/08            5
# 947    947   335984       Delhi  2008-04-19  2007/08            3
# 948    948   335983  Chandigarh  2008-04-19  2007/08            2
# 949    949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#      ...    WonBy Margin method Player_of_Match  \
# 0    ...  Wickets    7.0    NaN       HH Pandya
# 1    ...  Wickets    7.0    NaN      JC Buttler
# 2    ...     Runs   14.0    NaN      RM Patidar
# 3    ...  Wickets    7.0    NaN       DA Miller
# 4    ...  Wickets    5.0    NaN   Harpreet Brar
# ..   ...      ...    ...    ...             ...
# 945  ...  Wickets    5.0    NaN       DJ Hussey
# 946  ...  Wickets    5.0    NaN      MV Boucher
# 947  ...  Wickets    9.0    NaN     MF Maharoof
# 948  ...     Runs   33.0    NaN      MEK Hussey
# 949  ...     Runs  140.0    NaN     BB McCullum
#
#                                           Team1Players  \
# 0    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4    ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..                                                 ...
# 945  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 country     code
# 0       Nitin Menon   india    RRvGT
# 1       Nitin Menon   india   RCBvRR
# 2          MA Gough   india  RCBvLSG
# 3         VK Sharma   india    RRvGT
# 4     NA Patwardhan   india    SHvPK
# ..              ...     ...      ...
# 945     K Hariharan   india   KKRvDC
# 946       DJ Harper   india   MIvRCB
# 947  GA Pratapkumar   india    DDvRR
# 948      SL Shastri   india  KXPvCSK
# 949     RE Koertzen   india  RCBvKKR
#
# [950 rows x 23 columns]

# %%
# 76 rename
ipl.rename(columns={'indeex':'No.'})
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...    WonBy Margin method  Player_of_Match  \
# 0            bat  ...  Wickets    7.0    NaN        HH Pandya
# 1          field  ...  Wickets    7.0    NaN       JC Buttler
# 2          field  ...     Runs   14.0    NaN       RM Patidar
# 3          field  ...  Wickets    7.0    NaN        DA Miller
# 4            bat  ...  Wickets    5.0    NaN    Harpreet Brar
# ..           ...  ...      ...    ...    ...              ...
# 945          bat  ...  Wickets    5.0    NaN        DJ Hussey
# 946          bat  ...  Wickets    5.0    NaN       MV Boucher
# 947          bat  ...  Wickets    9.0    NaN      MF Maharoof
# 948          bat  ...     Runs   33.0    NaN       MEK Hussey
# 949        field  ...     Runs  140.0    NaN      BB McCullum
#
#                                           Team1Players  \
# 0    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4    ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..                                                 ...
# 945  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 country     code
# 0       Nitin Menon   india    RRvGT
# 1       Nitin Menon   india   RCBvRR
# 2          MA Gough   india  RCBvLSG
# 3         VK Sharma   india    RRvGT
# 4     NA Patwardhan   india    SHvPK
# ..              ...     ...      ...
# 945     K Hariharan   india   KKRvDC
# 946       DJ Harper   india   MIvRCB
# 947  GA Pratapkumar   india    DDvRR
# 948      SL Shastri   india  KXPvCSK
# 949     RE Koertzen   india  RCBvKKR
#
# [950 rows x 22 columns]

# %%
# 77 nunique
ipl.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# country              1
# code               167
# dtype: int64

# %%
# 78 isnull
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  ...  WonBy  Margin  method  Player_of_Match  \
# 0         False         False  ...  False   False    True            False
# 1         False         False  ...  False   False    True            False
# 2         False         False  ...  False   False    True            False
# 3         False         False  ...  False   False    True            False
# 4         False         False  ...  False   False    True            False
# ..          ...           ...  ...    ...     ...     ...              ...
# 945       False         False  ...  False   False    True            False
# 946       False         False  ...  False   False    True            False
# 947       False         False  ...  False   False    True            False
# 948       False         False  ...  False   False    True            False
# 949       False         False  ...  False   False    True            False
#
#      Team1Players  Team2Players  Umpire1  Umpire2  country   code
# 0           False         False    False    False    False  False
# 1           False         False    False    False    False  False
# 2           False         False    False    False    False  False
# 3           False         False    False    False    False  False
# 4           False         False    False    False    False  False
# ..            ...           ...      ...      ...      ...    ...
# 945         False         False    False    False    False  False
# 946         False         False    False    False    False  False
# 947         False         False    False    False    False  False
# 948         False         False    False    False    False  False
# 949         False         False    False    False    False  False
#
# [950 rows x 22 columns]

# %%
# 79 notnull  -> reverse
ipl.notnull()
# Out:
#        ID  City  Date  Season  MatchNumber  Team1  Team2  Venue  TossWinner  \
# 0    True  True  True    True         True   True   True   True        True
# 1    True  True  True    True         True   True   True   True        True
# 2    True  True  True    True         True   True   True   True        True
# 3    True  True  True    True         True   True   True   True        True
# 4    True  True  True    True         True   True   True   True        True
# ..    ...   ...   ...     ...          ...    ...    ...    ...         ...
# 945  True  True  True    True         True   True   True   True        True
# 946  True  True  True    True         True   True   True   True        True
# 947  True  True  True    True         True   True   True   True        True
# 948  True  True  True    True         True   True   True   True        True
# 949  True  True  True    True         True   True   True   True        True
#
#      TossDecision  ...  WonBy  Margin  method  Player_of_Match  Team1Players  \
# 0            True  ...   True    True   False             True          True
# 1            True  ...   True    True   False             True          True
# 2            True  ...   True    True   False             True          True
# 3            True  ...   True    True   False             True          True
# 4            True  ...   True    True   False             True          True
# ..            ...  ...    ...     ...     ...              ...           ...
# 945          True  ...   True    True   False             True          True
# 946          True  ...   True    True   False             True          True
# 947          True  ...   True    True   False             True          True
# 948          True  ...   True    True   False             True          True
# 949          True  ...   True    True   False             True          True
#
#      Team2Players  Umpire1  Umpire2  country  code
# 0            True     True     True     True  True
# 1            True     True     True     True  True
# 2            True     True     True     True  True
# 3            True     True     True     True  True
# 4            True     True     True     True  True
# ..            ...      ...      ...      ...   ...
# 945          True     True     True     True  True
# 946          True     True     True     True  True
# 947          True     True     True     True  True
# 948          True     True     True     True  True
# 949          True     True     True     True  True
#
# [950 rows x 22 columns]

# %%
# 80 dropna  --> by default - how='any'
ipl.dropna()    #-> dropna(subset=['name'])
# Out:
#           ID           City        Date   Season MatchNumber  \
# 282  1136592          Delhi  2018-05-02     2018          32
# 296  1136578        Kolkata  2018-04-21     2018          18
# 308  1136566         Jaipur  2018-04-11     2018           6
# 316  1082648      Bangalore  2017-05-17     2017  Eliminator
# 383   980999      Bangalore  2016-05-18     2016          50
# 384   980997  Visakhapatnam  2016-05-17     2016          49
# 389   980989        Kolkata  2016-05-14     2016          45
# 411   980943      Hyderabad  2016-04-26     2016          22
# 441   829807      Hyderabad  2015-05-15     2015          52
# 472   829743  Visakhapatnam  2015-04-22     2015          19
# 520   733993          Delhi  2014-05-10     2014          32
# 717   501255      Bangalore  2011-05-14     2011          58
# 728   501245        Kolkata  2011-05-07     2011          48
# 757   501215          Kochi  2011-04-18     2011          18
# 860   392214      Centurion  2009-05-07     2009          34
# 886   392186         Durban  2009-04-21     2009           6
# 889   392183      Cape Town  2009-04-19     2009           3
# 908   336025        Kolkata  2008-05-18  2007/08          41
# 910   336022          Delhi  2008-05-17  2007/08          40
#
#                            Team1                        Team2  \
# 282             Delhi Daredevils             Rajasthan Royals
# 296        Kolkata Knight Riders              Kings XI Punjab
# 308             Rajasthan Royals             Delhi Daredevils
# 316          Sunrisers Hyderabad        Kolkata Knight Riders
# 383  Royal Challengers Bangalore              Kings XI Punjab
# 384      Rising Pune Supergiants             Delhi Daredevils
# 389        Kolkata Knight Riders      Rising Pune Supergiants
# 411          Sunrisers Hyderabad      Rising Pune Supergiants
# 441          Sunrisers Hyderabad  Royal Challengers Bangalore
# 472          Sunrisers Hyderabad        Kolkata Knight Riders
# 520             Delhi Daredevils          Sunrisers Hyderabad
# 717  Royal Challengers Bangalore        Kolkata Knight Riders
# 728        Kolkata Knight Riders          Chennai Super Kings
# 757         Kochi Tuskers Kerala          Chennai Super Kings
# 860          Chennai Super Kings              Kings XI Punjab
# 886              Kings XI Punjab        Kolkata Knight Riders
# 889             Delhi Daredevils              Kings XI Punjab
# 908        Kolkata Knight Riders          Chennai Super Kings
# 910             Delhi Daredevils              Kings XI Punjab
#
#                                                  Venue  \
# 282                               Arun Jaitley Stadium
# 296                                       Eden Gardens
# 308                             Sawai Mansingh Stadium
# 316                              M Chinnaswamy Stadium
# 383                              M Chinnaswamy Stadium
# 384  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 389                                       Eden Gardens
# 411          Rajiv Gandhi International Stadium, Uppal
# 441          Rajiv Gandhi International Stadium, Uppal
# 472  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 520                                   Feroz Shah Kotla
# 717                              M Chinnaswamy Stadium
# 728                                       Eden Gardens
# 757                                      Nehru Stadium
# 860                                    SuperSport Park
# 886                                          Kingsmead
# 889                                           Newlands
# 908                                       Eden Gardens
# 910                                   Feroz Shah Kotla
#
#                       TossWinner TossDecision  ...    WonBy Margin method  \
# 282             Rajasthan Royals        field  ...     Runs    4.0    D/L
# 296              Kings XI Punjab        field  ...  Wickets    9.0    D/L
# 308             Delhi Daredevils        field  ...     Runs   10.0    D/L
# 316        Kolkata Knight Riders        field  ...  Wickets    7.0    D/L
# 383              Kings XI Punjab        field  ...     Runs   82.0    D/L
# 384      Rising Pune Supergiants        field  ...     Runs   19.0    D/L
# 389      Rising Pune Supergiants          bat  ...  Wickets    8.0    D/L
# 411      Rising Pune Supergiants        field  ...     Runs   34.0    D/L
# 441          Sunrisers Hyderabad          bat  ...  Wickets    6.0    D/L
# 472        Kolkata Knight Riders        field  ...     Runs   16.0    D/L
# 520          Sunrisers Hyderabad        field  ...  Wickets    8.0    D/L
# 717  Royal Challengers Bangalore        field  ...  Wickets    4.0    D/L
# 728          Chennai Super Kings          bat  ...     Runs   10.0    D/L
# 757         Kochi Tuskers Kerala        field  ...  Wickets    7.0    D/L
# 860          Chennai Super Kings          bat  ...     Runs   12.0    D/L
# 886        Kolkata Knight Riders        field  ...     Runs   11.0    D/L
# 889             Delhi Daredevils        field  ...  Wickets   10.0    D/L
# 908        Kolkata Knight Riders          bat  ...     Runs    3.0    D/L
# 910             Delhi Daredevils          bat  ...     Runs    6.0    D/L
#
#       Player_of_Match                                       Team1Players  \
# 282           RR Pant  ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', '...
# 296          KL Rahul  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...
# 308         SV Samson  ['AM Rahane', 'DJM Short', 'BA Stokes', 'SV Sa...
# 316   NM Coulter-Nile  ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yu...
# 383           V Kohli  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL ...
# 384          AB Dinda  ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS T...
# 389         YK Pathan  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
# 411          AB Dinda  ['DA Warner', 'S Dhawan', 'AP Tare', 'EJG Morg...
# 441           V Kohli  ['DA Warner', 'S Dhawan', 'MC Henriques', 'EJG...
# 472         DA Warner  ['S Dhawan', 'DA Warner', 'RS Bopara', 'NV Ojh...
# 520          DW Steyn  ['Q de Kock', 'KP Pietersen', 'MA Agarwal', 'K...
# 717          CH Gayle  ['CH Gayle', 'LA Pomersbach', 'V Kohli', 'AB d...
# 728     Iqbal Abdulla  ['EJG Morgan', 'JH Kallis', 'G Gambhir', 'MK T...
# 757       BB McCullum  ['BB McCullum', 'DPMD Jayawardene', 'PA Patel'...
# 860         ML Hayden  ['S Badrinath', 'ML Hayden', 'SK Raina', 'MS D...
# 886          CH Gayle  ['RS Bopara', 'K Goel', 'IK Pathan', 'KC Sanga...
# 889        DL Vettori  ['G Gambhir', 'V Sehwag', 'TM Dilshan', 'AB de...
# 908           M Ntini  ['Salman Butt', 'Mohammad Hafeez', 'SC Ganguly...
# 910  DPMD Jayawardene  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dils...
#
#                                           Team2Players                Umpire1  \
# 282  ['DJM Short', 'JC Buttler', 'SV Samson', 'BA S...              CK Nandan
# 296  ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nai...             A Deshmukh
# 308  ['GJ Maxwell', 'C Munro', 'RR Pant', 'CH Morri...  KN Ananthapadmanabhan
# 316  ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gamb...           AK Chaudhary
# 383  ['M Vijay', 'HM Amla', 'WP Saha', 'DA Miller',...  KN Ananthapadmanabhan
# 384  ['Q de Kock', 'SS Iyer', 'KK Nair', 'SV Samson...            Nitin Menon
# 389  ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS T...         A Nand Kishore
# 411  ['AM Rahane', 'F du Plessis', 'SPD Smith', 'MS...            AY Dandekar
# 441  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'Man...           AK Chaudhary
# 472  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'AD R...         RK Illingworth
# 520  ['AJ Finch', 'S Dhawan', 'DA Warner', 'NV Ojha...           RM Deshpande
# 717  ['JH Kallis', 'EJG Morgan', 'G Gambhir', 'MK T...            RE Koertzen
# 728  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badri...              Asad Rauf
# 757  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badri...            K Hariharan
# 860  ['S Sohal', 'SM Katich', 'K Goel', 'Yuvraj Sin...              DJ Harper
# 886  ['BB McCullum', 'CH Gayle', 'BJ Hodge', 'SC Ga...              DJ Harper
# 889  ['RS Bopara', 'K Goel', 'Yuvraj Singh', 'KC Sa...              MR Benson
# 908  ['PA Patel', 'SP Fleming', 'S Vidyut', 'SK Rai...              Asad Rauf
# 910  ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA P...         AV Jayaprakash
#
#              Umpire2 country     code
# 282        VK Sharma   india    DDvRR
# 296    C Shamshuddin   india  KKRvKXP
# 308      Nitin Menon   india    RRvDD
# 316      Nitin Menon   india   SHvKKR
# 383        M Erasmus   india  RCBvKXP
# 384    C Shamshuddin   india   RPSvDD
# 389     BNJ Oxenford   india  KKRvRPS
# 411        CK Nandan   india   SHvRPS
# 441  HDPK Dharmasena   india   SHvRCB
# 472      VA Kulkarni   india   SHvKKR
# 520     BNJ Oxenford   india    DDvSH
# 717        RB Tiffin   india  RCBvKKR
# 728       PR Reiffel   india  KKRvCSK
# 757          AL Hill   india  KTKvCSK
# 860   TH Wijewardene   india  CSKvKXP
# 886        SD Ranade   india  KXPvKKR
# 889        SD Ranade   india   DDvKXP
# 908      K Hariharan   india  KKRvCSK
# 910      RE Koertzen   india   DDvKXP
#
# [19 rows x 22 columns]

# %%
# 81 fillna   -> method= 'ffill'/'bfill'
ipl.fillna('unknown')
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...    WonBy Margin   method Player_of_Match  \
# 0            bat  ...  Wickets    7.0  unknown       HH Pandya
# 1          field  ...  Wickets    7.0  unknown      JC Buttler
# 2          field  ...     Runs   14.0  unknown      RM Patidar
# 3          field  ...  Wickets    7.0  unknown       DA Miller
# 4            bat  ...  Wickets    5.0  unknown   Harpreet Brar
# ..           ...  ...      ...    ...      ...             ...
# 945          bat  ...  Wickets    5.0  unknown       DJ Hussey
# 946          bat  ...  Wickets    5.0  unknown      MV Boucher
# 947          bat  ...  Wickets    9.0  unknown     MF Maharoof
# 948          bat  ...     Runs   33.0  unknown      MEK Hussey
# 949        field  ...     Runs  140.0  unknown     BB McCullum
#
#                                           Team1Players  \
# 0    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4    ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..                                                 ...
# 945  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 country     code
# 0       Nitin Menon   india    RRvGT
# 1       Nitin Menon   india   RCBvRR
# 2          MA Gough   india  RCBvLSG
# 3         VK Sharma   india    RRvGT
# 4     NA Patwardhan   india    SHvPK
# ..              ...     ...      ...
# 945     K Hariharan   india   KKRvDC
# 946       DJ Harper   india   MIvRCB
# 947  GA Pratapkumar   india    DDvRR
# 948      SL Shastri   india  KXPvCSK
# 949     RE Koertzen   india  RCBvKKR
#
# [950 rows x 22 columns]

# %%
# 82 drop duplicate
ipl.drop_duplicates()
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...    WonBy Margin method  Player_of_Match  \
# 0            bat  ...  Wickets    7.0    NaN        HH Pandya
# 1          field  ...  Wickets    7.0    NaN       JC Buttler
# 2          field  ...     Runs   14.0    NaN       RM Patidar
# 3          field  ...  Wickets    7.0    NaN        DA Miller
# 4            bat  ...  Wickets    5.0    NaN    Harpreet Brar
# ..           ...  ...      ...    ...    ...              ...
# 945          bat  ...  Wickets    5.0    NaN        DJ Hussey
# 946          bat  ...  Wickets    5.0    NaN       MV Boucher
# 947          bat  ...  Wickets    9.0    NaN      MF Maharoof
# 948          bat  ...     Runs   33.0    NaN       MEK Hussey
# 949        field  ...     Runs  140.0    NaN      BB McCullum
#
#                                           Team1Players  \
# 0    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4    ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..                                                 ...
# 945  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 country     code
# 0       Nitin Menon   india    RRvGT
# 1       Nitin Menon   india   RCBvRR
# 2          MA Gough   india  RCBvLSG
# 3         VK Sharma   india    RRvGT
# 4     NA Patwardhan   india    SHvPK
# ..              ...     ...      ...
# 945     K Hariharan   india   KKRvDC
# 946       DJ Harper   india   MIvRCB
# 947  GA Pratapkumar   india    DDvRR
# 948      SL Shastri   india  KXPvCSK
# 949     RE Koertzen   india  RCBvKKR
#
# [950 rows x 22 columns]

# %%
# 83 drop
ipl.drop(index=[0,3])
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 4    1304116      Mumbai  2022-05-22     2022           70
# 5    1304115      Mumbai  2022-05-21     2022           69
# 6    1304114      Mumbai  2022-05-20     2022           68
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 4            Sunrisers Hyderabad                 Punjab Kings
# 5                 Delhi Capitals               Mumbai Indians
# 6            Chennai Super Kings             Rajasthan Royals
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# 5                      Wankhede Stadium, Mumbai               Mumbai Indians
# 6                     Brabourne Stadium, Mumbai          Chennai Super Kings
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...    WonBy Margin method  Player_of_Match  \
# 1          field  ...  Wickets    7.0    NaN       JC Buttler
# 2          field  ...     Runs   14.0    NaN       RM Patidar
# 4            bat  ...  Wickets    5.0    NaN    Harpreet Brar
# 5          field  ...  Wickets    5.0    NaN        JJ Bumrah
# 6            bat  ...  Wickets    5.0    NaN         R Ashwin
# ..           ...  ...      ...    ...    ...              ...
# 945          bat  ...  Wickets    5.0    NaN        DJ Hussey
# 946          bat  ...  Wickets    5.0    NaN       MV Boucher
# 947          bat  ...  Wickets    9.0    NaN      MF Maharoof
# 948          bat  ...     Runs   33.0    NaN       MEK Hussey
# 949        field  ...     Runs  140.0    NaN      BB McCullum
#
#                                           Team1Players  \
# 1    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 4    ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# 5    ['PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant'...
# 6    ['RD Gaikwad', 'DP Conway', 'MM Ali', 'N Jagad...
# ..                                                 ...
# 945  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# 5    ['Ishan Kishan', 'RG Sharma', 'D Brevis', 'Til...    Nitin Menon
# 6    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 country     code
# 1       Nitin Menon   india   RCBvRR
# 2          MA Gough   india  RCBvLSG
# 4     NA Patwardhan   india    SHvPK
# 5      Tapan Sharma   india    DCvMI
# 6     NA Patwardhan   india   CSKvRR
# ..              ...     ...      ...
# 945     K Hariharan   india   KKRvDC
# 946       DJ Harper   india   MIvRCB
# 947  GA Pratapkumar   india    DDvRR
# 948      SL Shastri   india  KXPvCSK
# 949     RE Koertzen   india  RCBvKKR
#
# [948 rows x 22 columns]

# %%
# 84 apply
ipl['MatchNumber'].apply(lambda x:'Final')
# Out:
# 0      Final
# 1      Final
# 2      Final
# 3      Final
# 4      Final
#        ...
# 945    Final
# 946    Final
# 947    Final
# 948    Final
# 949    Final
# Name: MatchNumber, Length: 950, dtype: object

# %%
# 85 isin

# %%
# 86 corr

# %%
# 87 nlargest
ipl['ID'].nlargest()
# Out:
# 0    1312200
# 1    1312199
# 2    1312198
# 3    1312197
# 4    1304116
# Name: ID, dtype: int64

# %%
# 88 nsmallest
ipl.ID.nsmallest()
# Out:
# 949    335982
# 948    335983
# 947    335984
# 946    335985
# 945    335986
# Name: ID, dtype: int64

# %%
# 89 insert

# %%
# 90 copy
ipl['Player_of_Match'].copy()
# Out:
# 0          HH Pandya
# 1         JC Buttler
# 2         RM Patidar
# 3          DA Miller
# 4      Harpreet Brar
#            ...
# 945        DJ Hussey
# 946       MV Boucher
# 947      MF Maharoof
# 948       MEK Hussey
# 949      BB McCullum
# Name: Player_of_Match, Length: 950, dtype: object
